# %% [markdown]
# #Devendra jangir

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/penguins.csv')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.shape
# Out:
# (344, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df['bill_length_mm'].fillna(df['bill_length_mm'].median(),inplace =True)
df['bill_depth_mm'].fillna(df['bill_depth_mm'].median(),inplace =True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace =True)
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace =True)

# %%
df['sex'].fillna(df['sex'].mode(),inplace =True)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# dtype: int64

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# bill_length_mm       False
# bill_depth_mm        False
# flipper_length_mm    False
# body_mass_g          False
# sex                   True
# dtype: bool

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.925000      17.152035         200.892442  4200.872093
# std          5.443792       1.969060          14.023826   799.696532
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.	species.nunique()
# Out:
# 3

# %%
df.	species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.	species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# Name: sex, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235000           0.655858
# bill_depth_mm           -0.235000       1.000000          -0.583832
# flipper_length_mm        0.655858      -0.583832           1.000000
# body_mass_g              0.594925      -0.471942           0.871221
#
#                    body_mass_g
# bill_length_mm        0.594925
# bill_depth_mm        -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %%
sns.distplot(df.bill_length_mm)
# Out:
# <ipython-input-24-10865be26cc8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.bill_length_mm)
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.distplot(df.bill_depth_mm	)
# Out:
# <ipython-input-25-ed732cfaa844>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.bill_depth_mm	)
# <Axes: xlabel='bill_depth_mm', ylabel='Density'>

# %%
plt.pie(df.sex.value_counts(),[0,0.1],labels = ['male','female'],autopct ='%1.1f%%',shadow = True,colors = ['purple','yellow'],)
plt.title('sex')
plt.show()

# %%
plt.pie(df.species.value_counts(),[0,0.1,0],labels = ['Adelie','Chinstrap','Gentoo'],autopct ='%1.1f%%',shadow = True,colors = ['red','yellow','orange'],)
plt.title('species')
plt.show()

# %%
sns.barplot(x =df.species.value_counts().index,y =df.species.value_counts() )
# Out:
# <Axes: ylabel='species'>

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen           39.10           18.7              181.0
# 1  Adelie  Torgersen           39.50           17.4              186.0
# 2  Adelie  Torgersen           40.30           18.0              195.0
# 3  Adelie  Torgersen           44.45           17.3              197.0
# 4  Adelie  Torgersen           36.70           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# **Bivariate** **Analysis**

# %%
sns.lineplot(x = df.species,y=df.sex)
# Out:
# <Axes: xlabel='species', ylabel='sex'>

# %%
sns.lineplot(x = df.island	,y=df.sex)
# Out:
# <Axes: xlabel='island', ylabel='sex'>

# %%
sns.lineplot(x = df.bill_length_mm,y=df.sex)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='sex'>

# %%
sns.lineplot(x = df.body_mass_g,y=df.sex)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-35-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen           39.10           18.7              181.0
# 1  Adelie  Torgersen           39.50           17.4              186.0
# 2  Adelie  Torgersen           40.30           18.0              195.0
# 3  Adelie  Torgersen           44.45           17.3              197.0
# 4  Adelie  Torgersen           36.70           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %%
sns.boxplot(df.bill_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# **1**.**Label** **Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen           39.10           18.7              181.0
# 1  Adelie  Torgersen           39.50           17.4              186.0
# 2  Adelie  Torgersen           40.30           18.0              195.0
# 3  Adelie  Torgersen           44.45           17.3              197.0
# 4  Adelie  Torgersen           36.70           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %%
df.species = le.fit_transform(df.species)
df.island	 = le.fit_transform(df.island	)
df.sex	 = le.fit_transform(df.sex	)

# %%
df.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0       2           39.10           18.7              181.0
# 1        0       2           39.50           17.4              186.0
# 2        0       2           40.30           18.0              195.0
# 3        0       2           44.45           17.3              197.0
# 4        0       2           36.70           19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    2
# 4       3450.0    0

# %%
df.corr().sex.sort_values(ascending=False)
# Out:
# sex                  1.000000
# body_mass_g          0.351136
# bill_depth_mm        0.306402
# bill_length_mm       0.267500
# flipper_length_mm    0.207430
# island               0.029246
# species              0.008559
# Name: sex, dtype: float64

# %%
y = df['sex']
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    2
# 4    0
# Name: sex, dtype: int64

# %%
X =df.drop(columns =['sex'],axis =1)
X.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0       2           39.10           18.7              181.0
# 1        0       2           39.50           17.4              186.0
# 2        0       2           40.30           18.0              195.0
# 3        0       2           44.45           17.3              197.0
# 4        0       2           36.70           19.3              193.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 3       4050.0
# 4       3450.0

# %% [markdown]
# **Scaling on independent variables**

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0.0     1.0        0.254545       0.666667           0.152542
# 1      0.0     1.0        0.269091       0.511905           0.237288
# 2      0.0     1.0        0.298182       0.583333           0.389831
# 3      0.0     1.0        0.449091       0.500000           0.423729
# 4      0.0     1.0        0.167273       0.738095           0.355932
#
#    body_mass_g
# 0     0.291667
# 1     0.305556
# 2     0.152778
# 3     0.375000
# 4     0.208333

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10)

# %%
X_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
X_test.shape
# Out:
# (104, 6)
